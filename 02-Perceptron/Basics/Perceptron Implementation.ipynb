# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing the Dataset

# %%
dataset = pd.read_csv('placement.csv')
dataset.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
x = dataset.iloc[:,0:2]
y = dataset.iloc[:,-1]

# %% [markdown]
# #### Visualising the Data

# %%
plt.figure( figsize = (5.5, 4))
sns.scatterplot(dataset['cgpa'], dataset['resume_score'], hue = dataset['placed'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cgpa', ylabel='resume_score'>

# %% [markdown]
# #### Importing Perceptron Library

# %%
from sklearn.linear_model import Perceptron
perceptron = Perceptron()

# %%
perceptron.fit(x, y)
# Out:
# Perceptron()

# %% [markdown]
# #### Checking the values being used to predict results

# %%
print("Value of weights used to predict results :", perceptron.coef_)
print("Value of bias used to predict results :", perceptron.intercept_)
# Out:
# Value of weights used to predict results : [[ 40.26 -36.  ]]
# Value of bias used to predict results : [-25.]

# %%
#### Visualising how perceptron is

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plt.figure(figsize = (10.5, 8))
plot_decision_regions(x.values, y.values, clf=perceptron, legend=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <AxesSubplot:>
